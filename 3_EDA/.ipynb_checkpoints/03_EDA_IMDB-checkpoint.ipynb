# %% [markdown]
# # 3. IMDB_Classification_EDA<a id='2_Data_wrangling'></a>

# %% [markdown]
# ## 3.1 Table of Contents<a id='2.1_Contents'></a>
# * 3. Bank_Churnrate_EDA
#   * 3.1 Table of Contents
#   * 3.2 Introduction
#   * 3.3 Imports
#   * 3.4 Load movie_df_clean Data & Audit
#   * 3.5 Explore The Data
#     * 3.5.1 Filtering features of interest
#     * 3.5.2 Visualization for Class Balance
#   * 3.6 Save Data
#   * 3.7 Summary

# %% [markdown]
# ## 3.2 Introduction

# %% [markdown]
# Further Analysis will be conducted with the movie_df_clean dataset to further assess the dataset and glean any further insights regarding the dataset's feature balance for genres.

# %% [markdown]
# ## 3.3 Imports<a id='2.3_Imports'></a>

# %% [markdown]
# Importing all appropriate packages in order to perform further EDA for the previously "cleaned" movie dataset.

# %%
#Import requests, json, pandas, matplotlib.pyplot, seaborn, and numpy
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## 3.4 Load Movie Dataset & Continued Wrangling

# %% [markdown]
# ### 3.4.1 Load & Assess Dataset

# %%
#Dropped first column since it was unnamed 
#Code to remove the first column for the dataset: https://www.statology.org/drop-unnamed-column-pandas/
movie_df = pd.read_csv('C:/Users/tpooz/OneDrive/Desktop/Data_Science_BootCamp_2023/SpringBoard_Github/IMDB_Classification/0_Datasets/movie_df_clean.csv', index_col=0)

# %% [markdown]
# Auditing the dataset with .info() and .head() displaying the first few records.

# %%
#info method on movie_df_clean to see a summary of the data
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3973 entries, 0 to 3972
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   level_0           3973 non-null   int64
#  1   index             3973 non-null   int64
#  2   id                3973 non-null   object
#  3   image             3973 non-null   object
#  4   title             3973 non-null   object
#  5   description       3973 non-null   object
#  6   runtimeStr        3973 non-null   object
#  7   genres            3940 non-null   object
#  8   genreList         3973 non-null   object
#  9   contentRating     3973 non-null   object
#  10  imDbRating        3973 non-null   float64
#  11  imDbRatingVotes   3973 non-null   int64
#  12  metacriticRating  3973 non-null   object
#  13  plot              3942 non-null   object
#  14  stars             0 non-null      float64
#  15  starList          3973 non-null   object
#  16  Genre_1           3940 non-null   object
#  17  Genre_2           3973 non-null   object
#  18  Genre_3           3973 non-null   object
# dtypes: float64(2), int64(3), object(14)
# memory usage: 620.8+ KB

# %% [markdown]
# Looking at the above results, it appears that indeed there are movies listed that have no genres classified with them. These movies will be filtered out of the dataset as the image classifier needs predefined labels in terms for training of label categorization.

# %%
#Replacing all values with NaN as 'None' for ease of filtering. Code to replace values found on https://stackoverflow.com/questions/66760733/change-nan-to-none-in-pandas-dataframe
#Locating all movies with 'None' for their Genre.
movie_df = movie_df.replace({np.nan:'None'})
movie_df[movie_df['genres'] == 'None']
# Out:
#       level_0  index          id  \
# 476       476    484   tt0114409
# 477       477    485   tt0310978
# 735       735    744   tt0384129
# 1067     1067   1091   tt0335591
# 1078     1078   1103   tt6447558
# 2989    48 mins   None        []            PG         0.0                0
# 3001    49 mins   None        []             G         0.0                0
# 3009    88 mins   None        []            PG         0.0                0
# 3010    45 mins   None        []            PG         0.0                0
# 3012   112 mins   None        []            PG         0.0                0
# 3015   248 mins   None        []             G         6.1               10
# 3016   103 mins   None        []             G         0.0                0
# 3174   103 mins   None        []            PG         8.7               39
# 3184   115 mins   None        []            PG         8.1               22
# 3209       None   None        []             G         0.0                0
#
#      metacriticRating                                               plot  \
# 476              None  Shakuhachi - the Japanese flute has a very rel...
# 477              None                                               None
# 735              None                                               None
# 1067             None  What if Jesus were born in the year 2002 to a ...
# 1078             None                                               None
# 1492             None                                               None
# 1498             None  Challenged by Harvard Magazine to prove "intel...
# 1776             None  Following the lives of people that push, pull,...
# 1777             None  In this documentary, we go underwater to explo...
# 1778             None  An old man has an enchanting encounter with a ...
# 2108             None  Tom Cholmondeley, heir to the largest white-ow...
# 2113             None  The Japanese sword ... prized as much for its ...
# 2116             None  A heart warming journey among Tibetan Buddhist...
# 2287             None  Fabrice Champion was an accomplished trapeze a...
# 2412             None  Follow a group of researchers traveling to Dar...
# 2460             None  There's a new scourge causing mayhem in Great ...
# 2617             None  Starting in 1967 and continuing for 11 straigh...
# 2629             None  Set in Corsica and Paris in the year 1841, thi...
# 2819             None  When Alabama's Sarah Patterson and Georgia's S...
# 2824             None  Recorded at Union Transfer in Philadelphia and...
# 2829             None  Experience the power of the Ultimate Warrior l...
# 2962             None  When a sugar shortage threatens the annual Fes...
# 2980             None  TransWorld SNOWboarding presents 20 Tricks Vol...
# 2989             None  The ThirtyTwo team celebrated its 20-year mile...
# 3001             None  This special edition travel film has pop up bu...
# 3009             None  Trax "Evolution of snow bikes" will inspire mo...
# 3010             None  What makes you happy? Legendary pro snowboarde...
# 3012             None  In a winter where little snow fell and summer-...
# 3015             None  The official review of another sensational edi...
# 3016             None  An All-BartÃ³k programme featuring one of the ...
# 3174             None  Like Jim Carrey's Eternal Sunshine of the Spot...
# 3184             None  It's America's most iconic residence - symbol ...
# 3209             None                                               None
#
#      stars starList Genre_1 Genre_2 Genre_3
# 476   None       []    None    None    None
# 477   None       []    None    None    None
# 735   None       []    None    None    None
# 1067  None       []    None    None    None
# 1078  None       []    None    None    None
# 1492  None       []    None    None    None
# 1498  None       []    None    None    None
# 1776  None       []    None    None    None
# 1777  None       []    None    None    None
# 1778  None       []    None    None    None
# 2108  None       []    None    None    None
# 2113  None       []    None    None    None
# 2116  None       []    None    None    None
# 2287  None       []    None    None    None
# 2412  None       []    None    None    None
# 2460  None       []    None    None    None
# 2617  None       []    None    None    None
# 2629  None       []    None    None    None
# 2819  None       []    None    None    None
# 2824  None       []    None    None    None
# 2829  None       []    None    None    None
# 2962  None       []    None    None    None
# 2980  None       []    None    None    None
# 2989  None       []    None    None    None
# 3001  None       []    None    None    None
# 3009  None       []    None    None    None
# 3010  None       []    None    None    None
# 3012  None       []    None    None    None
# 3015  None       []    None    None    None
# 3016  None       []    None    None    None
# 3174  None       []    None    None    None
# 3184  None       []    None    None    None
# 3209  None       []    None    None    None

# %%
#Filtering out movies with 'None' values for their genre
movie_df = movie_df[movie_df['genres'] != 'None']
movie_df = movie_df[['id', 'image', 'Genre_1', 'Genre_2', 'Genre_3']]
movie_df = movie_df.reset_index()

# %%
movie_df.shape
# Out:
# (3940, 6)

# %% [markdown]
# ### 3.4.2 Retrieve Image Data None Null Genre Movies

# %% [markdown]
# Looking at the above results, it seems when the dataset is reloaded again to this notebook, there are some movies with no genre designation. Therefore, images only from movies with a genre designation will be re-wrangled and stored as only movies with a genre will be useful for the image classifier.

# %%
#For loop to save the image naming it with the movie id from the url. Images are then moved into an the approrpaite file folder 
#Actual code block not able to be retrieved for addressing errors in requests but it diagnosed error cause to not having an appropriate headers to accept application/json
#Similar explanation for headers seen on ChatGPT search https://chat.openai.com/c/85f15339-0e94-4816-a444-bf82bc5fad63 with start phrase: Python, remote forcibly closed connection, how to fix get request
#Code for handling timeouts in get requests found on https://stackoverflow.com/questions/21965484/timeout-for-python-requests-get-entire-response
for i in range(len(movie_df)-1):
    url = movie_df['image'][i]
    headers = {'accept':'application/json',}
    data = requests.get(url, headers=headers, timeout=60).content
    f = open(f"{movie_df['id'][i]}.jpg",'wb')
    f.write(data)
    f.close()

# %% [markdown]
# ## 3.5 Explore The Data

# %% [markdown]
# ### 3.5.1 Filtering features of interest

# %% [markdown]
# Filter movie_df_clean to just include features such as id and genres.

# %%
movie_df_filter = movie_df[['id', 'Genre_1', 'Genre_2', 'Genre_3']]
movie_df_filter.head()
# Out:
#           id    Genre_1     Genre_2    Genre_3
# 0  tt0099785     Comedy      Family       None
# 1  tt0099810     Action   Adventure   Thriller
# 2  tt0100758     Action   Adventure     Comedy
# 3  tt0099088  Adventure      Comedy     Sci-Fi
# 4  tt0099422     Action      Comedy      Crime

# %%
movie_df_filter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3940 entries, 0 to 3939
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3940 non-null   object
#  1   Genre_1  3940 non-null   object
#  2   Genre_2  3940 non-null   object
#  3   Genre_3  3940 non-null   object
# dtypes: object(4)
# memory usage: 123.2+ KB

# %%
#Reverting 'None' value to NaN in order to identify feature balance for movie genres
movie_df_filter = movie_df_filter.replace({'None':np.nan})

# %%
movie_df_filter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3940 entries, 0 to 3939
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3940 non-null   object
#  1   Genre_1  3940 non-null   object
#  2   Genre_2  2920 non-null   object
#  3   Genre_3  1991 non-null   object
# dtypes: object(4)
# memory usage: 123.2+ KB

# %% [markdown]
# Since the future image classifier will have multi-class label output, each genre column will need to be checked for class balance. What seems clear however are that few movies only have 2 genres or 1 genre listed where movies with only 2 genres are 2920/3940 or about 74% of the total movies and 1991/3940 or about 50% have only 1 genre listed.

# %%
#Reverting NaN genre for movies back to 'None' for vizulation of 'None' category for movie genre
movie_df_filter = movie_df_filter.replace({np.nan:'None'})
movie_df_filter.head()
# Out:
#           id    Genre_1     Genre_2    Genre_3
# 0  tt0099785     Comedy      Family       None
# 1  tt0099810     Action   Adventure   Thriller
# 2  tt0100758     Action   Adventure     Comedy
# 3  tt0099088  Adventure      Comedy     Sci-Fi
# 4  tt0099422     Action      Comedy      Crime

# %% [markdown]
# ### 3.5.2 Visualization for Class Balance

# %%
#Code to order genres based on descending value count found on https://stackoverflow.com/questions/46623583/order-categories-by-count-in-a-countplot
sns.countplot(data = movie_df_filter, x='Genre_1', order=movie_df_filter['Genre_1'].value_counts().index, palette='colorblind')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
sns.countplot(data = movie_df_filter, x='Genre_2', order=movie_df_filter['Genre_2'].value_counts().index, palette='colorblind')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
sns.countplot(data = movie_df_filter, x='Genre_3', order=movie_df_filter['Genre_3'].value_counts().index, palette='colorblind')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# Looking at the above plots, there is a clear class imbalance based on the types of genres for movies being represented within the dataset. The top 5 movie classes based on represenation are Comedy, Docomentaries, Animation, Drama, and Adventure. The top second class of genre label are None, Family, Adventure, Drama, and Comedy. The top 5 third class labels are None, Family, Comedy, Fantasy, and Romance. What also seems to be the case for the dataset is that if the Genre_2 has a 'None' within its value, Genre_3 also has a 'None' in its value which can be seen as intercollinearity between the values in the dataset. Therefore it seems as well from this dataset, most movies have either 1 or 2 genre class labels associated with them.

# %% [markdown]
# ## 3.6 Save data

# %%
#Dropped 'NA' values dataset shape
movie_df_filter.shape
# Out:
# (3940, 6)

# %%
# save the data to a new csv file
datapath = 'C:/Users/tpooz/OneDrive/Desktop/Data_Science_BootCamp_2023/SpringBoard_Github/IMDB_Classification/0_Datasets'
movie_df_filter.to_csv('C:/Users/tpooz/OneDrive/Desktop/Data_Science_BootCamp_2023/SpringBoard_Github/IMDB_Classification/0_Datasets/movie_df_filtered.csv')

# %% [markdown]
# ## 3.7 Summary

# %% [markdown]
# After a further analysis and "cleaning" of the dataset from dropping any movies with no genre label as well as filtering the dataset for key features of importance for the future image classifer, there is a definite class imbalance for the dataset. This makes sense however because of largely focusing on movies within the G or PG category which does limit how many movies would be represented for each of the classes. Based on the EDA, the top 5 genres for the first category are Comedy, Docomentaries, Animation, Drama, and Adventure. The second category are None, Family, Adventure, Drama, and Comedy. And for the third class label are None, Family, Comedy, Fantasy, and Romance. As mentioned it does seem that there is intercollineralty between the classes as if a movie has 'None' within its Genre_2 it also has a 'None' within Genre_3 as the genre labels are sequential. There aslo seems to be a larger amount of movies within the dataset with only 1 or 2 genre class labels.
#
# This class imbalance will be kept in mind when developing the image classification model and prior to implementing, the categorical values will be one-hot encoded prior to creating a respective training and test set.
