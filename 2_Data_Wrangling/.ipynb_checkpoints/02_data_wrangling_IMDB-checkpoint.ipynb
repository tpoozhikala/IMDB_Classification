# %% [markdown]
# # 2. IMDB_Data_Wrangling<a id='2_Data_wrangling'></a>

# %% [markdown]
# ## 2.1 Table of Contents<a id='2.1_Contents'></a>
# * 2. IMDB_Data_Wrangling
#   * 2.1 Table of Contents
#   * 2.2 Introduction
#   * 2.3 Imports
#   * 2.4 Retrieve IMDB Movie Data
#   * 2.5 Target Feature (Movie Genres)
#   * 2.6 Save data
#   * 2.7 Summary

# %% [markdown]
# ## 2.2 Introduction

# %% [markdown]
# In the Data Wrangling/Cleaning phase, data needs first be retrieved by the IMDB API Get request and then transformed into pandas dataframe for further manipulation and export to .csv.

# %% [markdown]
# ## 2.3 Imports<a id='2.3_Imports'></a>

# %% [markdown]
# Importing all appropriate packages in order to access requests and organize/clean json data to pandas dataframe.

# %%
#Import requests, json, pandas, numpy, matplotlib.pyplot, and seaborn
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from ydata_profiling import ProfileReport

# %% [markdown]
# ## 2.4 Retrieve IMDB Movie Data

# %% [markdown]
# Dataset is retrieved with movie data from 1990 to past year of 2023 with filtered setting of the API Request for G and PG rated movies based on the company's focus on Family Friendly Movies.

# %%
# Intialize start and end datetime for IMDB API Get request
start_year = ['1990-01-01', '1991-01-01', '1992-01-01', '1993-01-01', '1994-01-01', '1995-01-01', '1996-01-01', '1997-01-01','1998-01-01', '1999-01-01','2000-01-01', '2001-01-01', '2002-01-01', '2003-01-01', '2004-01-01', '2005-01-01', '2006-01-01', '2007-01-01', '2008-01-01', '2009-01-01', '2010-01-01', '2011-01-01', '2012-01-01', '2013-01-01', '2014-01-01', '2015-01-01', '2016-01-01', '2017-01-01', '2018-01-01', '2019-01-01', '2020-01-01', '2021-01-01', '2022-01-01', '2023-01-01']
end_year = ['1990-12-31', '1991-12-31', '1992-12-31', '1993-12-31', '1994-12-31', '1995-12-31', '1996-12-31', '1997-12-31','1998-12-31', '1999-12-31','2000-12-31', '2001-12-31', '2002-12-31', '2003-12-31', '2004-12-31', '2005-12-31', '2006-12-31', '2007-12-31', '2008-12-31', '2009-12-31', '2010-12-31', '2011-12-31', '2012-12-31', '2013-12-31', '2014-12-31', '2015-12-31', '2016-12-31', '2017-12-31', '2018-12-31', '2019-12-31', '2020-12-31', '2021-12-31', '2022-12-31', '2023-12-31']

# %%
#Created a function in order to generate API requests and convert the request into a Pandas Dataframe based on start and end year
#Code for API Get Request found on IMDB Website: https://imdb-api.com/api/#Search-header
#Code to convert json data into dict found on https://favtutor.com/blogs/string-to-dict-python
#Get keys from python dicts code found in https://tutorialdeep.com/knowhow/get-dictionary-value-key-python/
def imdb_data(start_year, end_year):
    url = f"https://tv-api.com/API/AdvancedSearch/k_8jnkh6yr?title_type=feature&release_date={start_year},{end_year}&certificates=us:G,us:PG&count=250"
    payload = {}
    headers = {}
    res = requests.request("GET", url, headers=headers, data=payload)
    movie_list = res.text.encode('utf8')
    movie_list_decode = json.loads(movie_list.decode('utf8'))
    movie_list = movie_list_decode['results']
    movie_df = pd.DataFrame(movie_list)
    return movie_df

# %%
#Created list of movie dataframes of movies from 1990 to 2023
movie_df_concat = []
for i in range(len(start_year)):
    movie_df_concat.append(imdb_data(start_year[i], end_year[i]))

# %%
#Joined the above dataframes to create a combinded dataframe for movie data from 1990 to 2023
#Code to join dataframes ignore_index found on https://www.statology.org/stack-pandas-dataframes/ and https://pandas.pydata.org/pandas-docs/version/1.3/reference/api/pandas.DataFrame.append.html
movie_df_total = pd.concat(movie_df_concat, ignore_index=True)
movie_df_total
# Out:
#               id                                              image  \
# 0      tt0099785  https://m.media-amazon.com/images/M/MV5BMzFkM2...
# 1      tt0099810  https://m.media-amazon.com/images/M/MV5BZDdkOD...
# 2      tt0100758  https://m.media-amazon.com/images/M/MV5BNzg3NT...
# 3      tt0099088  https://m.media-amazon.com/images/M/MV5BYjhlMG...
# 4      tt0099422  https://m.media-amazon.com/images/M/MV5BMzA5MD...
# ...          ...                                                ...
# 4054  tt15426874  https://m.media-amazon.com/images/M/MV5BNmIwZj...
# 4055  tt30133792                                               None
# 4056  tt27838714  https://m.media-amazon.com/images/M/MV5BYjkxNz...
# 4057  tt28018383                                               None
# 4058  tt15440520                                               None
#
#                                                   title description  \
# 0                                            Home Alone        1990
# 1                              The Hunt for Red October        1990
# 2                          Teenage Mutant Ninja Turtles        1990
# 3                           Back to the Future Part III        1990
# 4                                            Dick Tracy        1990
# ...                                                 ...         ...
# 4054          Seaper Powers: Mystery of the Blue Pearls        2023
# 4055   Justice League x RWBY: Super Heroes and Huntsmen        2023
# 4056                                                M&A        2023
# 4057  Graham Bullard Movie: Peanuts Meets the Loud H...        2023
# 4058                                Journey - The Movie        2023
#
#      runtimeStr                        genres  \
# 0      103 mins                Comedy, Family
# 1      135 mins   Action, Adventure, Thriller
# 2       93 mins     Action, Adventure, Comedy
# 3      118 mins     Adventure, Comedy, Sci-Fi
# 4      105 mins         Action, Comedy, Crime
# ...         ...                           ...
# 4054    66 mins                     Animation
# 4055       None  Animation, Action, Adventure
# 4056    84 mins                   Documentary
# 4057    89 mins     Adventure, Comedy, Family
# 4058    60 mins                        Sci-Fi
#
#                                               genreList contentRating  \
# 0     [{'key': 'Comedy', 'value': 'Comedy'}, {'key':...            PG
# 1     [{'key': 'Action', 'value': 'Action'}, {'key':...            PG
# 2     [{'key': 'Action', 'value': 'Action'}, {'key':...            PG
# 3     [{'key': 'Adventure', 'value': 'Adventure'}, {...            PG
# 4     [{'key': 'Action', 'value': 'Action'}, {'key':...            PG
# ...                                                 ...           ...
# 4054       [{'key': 'Animation', 'value': 'Animation'}]            PG
# 4055  [{'key': 'Animation', 'value': 'Animation'}, {...            PG
# 4056   [{'key': 'Documentary', 'value': 'Documentary'}]            PG
# 4057  [{'key': 'Adventure', 'value': 'Adventure'}, {...             G
# 4058             [{'key': 'Sci-Fi', 'value': 'Sci-Fi'}]             G
#
#      imDbRating imDbRatingVotes metacriticRating  \
# 0           7.7          645257               63
# 1           7.5          212075               58
# 2           6.8          103577               51
# 3           7.4          475051               55
# 4           6.2           65117               68
# ...         ...             ...              ...
# 4054          0               0             None
# 4055          0               0             None
# 4056          0               0             None
# 4057          0               0             None
# 4058          0               0             None
#
#                                                    plot stars starList
# 0     An eight-year-old troublemaker, mistakenly lef...             []
# 1     In November 1984, the Soviet Union's best subm...             []
# 2     Four teenage mutant ninja turtles emerge from ...             []
# 3     Stranded in 1955, Marty McFly learns about the...             []
# 4     The comic strip detective finds his life vastl...             []
# ...                                                 ...   ...      ...
# 4054  Emma works for NOAA as a diver and researcher....             []
# 4055  Justice League x RWBY: Super Heroes and Huntsm...             []
# 4056  Baby Boomers own 83% of businesses. It is $10 ...             []
# 4057  The Peanuts Gang and The Loud Family all have ...             []
# 4058  Explores all the In Earth and Out Earth places...             []
#
# [4059 rows x 14 columns]

# %% [markdown]
# Audited the IMDB Dataset with .head() and .info() methods.

# %%
movie_df_total.head()
# Out:
#           id                                              image  \
# 0  tt0099785  https://m.media-amazon.com/images/M/MV5BMzFkM2...
# 1  tt0099810  https://m.media-amazon.com/images/M/MV5BZDdkOD...
# 2  tt0100758  https://m.media-amazon.com/images/M/MV5BNzg3NT...
# 3  tt0099088  https://m.media-amazon.com/images/M/MV5BYjhlMG...
# 4  tt0099422  https://m.media-amazon.com/images/M/MV5BMzA5MD...
#
#                           title description runtimeStr  \
# 0                    Home Alone        1990   103 mins
# 1      The Hunt for Red October        1990   135 mins
# 2  Teenage Mutant Ninja Turtles        1990    93 mins
# 3   Back to the Future Part III        1990   118 mins
# 4                    Dick Tracy        1990   105 mins
#
#                         genres  \
# 0               Comedy, Family
# 1  Action, Adventure, Thriller
# 2    Action, Adventure, Comedy
# 3    Adventure, Comedy, Sci-Fi
# 4        Action, Comedy, Crime
#
#                                            genreList contentRating imDbRating  \
# 0  [{'key': 'Comedy', 'value': 'Comedy'}, {'key':...            PG        7.7
# 1  [{'key': 'Action', 'value': 'Action'}, {'key':...            PG        7.5
# 2  [{'key': 'Action', 'value': 'Action'}, {'key':...            PG        6.8
# 3  [{'key': 'Adventure', 'value': 'Adventure'}, {...            PG        7.4
# 4  [{'key': 'Action', 'value': 'Action'}, {'key':...            PG        6.2
#
#   imDbRatingVotes metacriticRating  \
# 0          645257               63
# 1          212075               58
# 2          103577               51
# 3          475051               55
# 4           65117               68
#
#                                                 plot stars starList
# 0  An eight-year-old troublemaker, mistakenly lef...             []
# 1  In November 1984, the Soviet Union's best subm...             []
# 2  Four teenage mutant ninja turtles emerge from ...             []
# 3  Stranded in 1955, Marty McFly learns about the...             []
# 4  The comic strip detective finds his life vastl...             []

# %%
movie_df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4059 entries, 0 to 4058
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                4059 non-null   object
#  1   image             3973 non-null   object
#  2   title             4059 non-null   object
#  3   description       4058 non-null   object
#  4   runtimeStr        4005 non-null   object
#  5   genres            4059 non-null   object
#  6   genreList         4059 non-null   object
#  7   contentRating     4058 non-null   object
#  8   imDbRating        4059 non-null   object
#  9   imDbRatingVotes   4059 non-null   object
#  10  metacriticRating  1471 non-null   object
#  11  plot              4059 non-null   object
#  12  stars             4059 non-null   object
#  13  starList          4059 non-null   object
# dtypes: object(14)
# memory usage: 444.1+ KB

# %% [markdown]
# Looking at the above results, we can see that the "image" column for the data has some null values. However, all rows seem to have a genre value, but will be investigated further. Rows with missing image data will be dropped as these will not be usable for future image classification.

# %%
#Dropped null values for image column and reset index
#Code to reset index found on https://www.geeksforgeeks.org/pandas-how-to-reset-index-in-a-given-dataframe/
movie_df_total['image'] = movie_df_total['image'].dropna()
movie_df_dropped = movie_df_total.dropna(subset=['image'])
movie_df_dropped = movie_df_dropped.reset_index()
movie_df_dropped.shape
# Out:
# (3973, 15)

# %%
movie_df_dropped.head()
# Out:
#    index         id                                              image  \
# 0      0  tt0099785  https://m.media-amazon.com/images/M/MV5BMzFkM2...
# 1      1  tt0099810  https://m.media-amazon.com/images/M/MV5BZDdkOD...
# 2      2  tt0100758  https://m.media-amazon.com/images/M/MV5BNzg3NT...
# 3      3  tt0099088  https://m.media-amazon.com/images/M/MV5BYjhlMG...
# 4      4  tt0099422  https://m.media-amazon.com/images/M/MV5BMzA5MD...
#
#                           title description runtimeStr  \
# 0                    Home Alone        1990   103 mins
# 1      The Hunt for Red October        1990   135 mins
# 2  Teenage Mutant Ninja Turtles        1990    93 mins
# 3   Back to the Future Part III        1990   118 mins
# 4                    Dick Tracy        1990   105 mins
#
#                         genres  \
# 0               Comedy, Family
# 1  Action, Adventure, Thriller
# 2    Action, Adventure, Comedy
# 3    Adventure, Comedy, Sci-Fi
# 4        Action, Comedy, Crime
#
#                                            genreList contentRating imDbRating  \
# 0  [{'key': 'Comedy', 'value': 'Comedy'}, {'key':...            PG        7.7
# 1  [{'key': 'Action', 'value': 'Action'}, {'key':...            PG        7.5
# 2  [{'key': 'Action', 'value': 'Action'}, {'key':...            PG        6.8
# 3  [{'key': 'Adventure', 'value': 'Adventure'}, {...            PG        7.4
# 4  [{'key': 'Action', 'value': 'Action'}, {'key':...            PG        6.2
#
#   imDbRatingVotes metacriticRating  \
# 0          645257               63
# 1          212075               58
# 2          103577               51
# 3          475051               55
# 4           65117               68
#
#                                                 plot stars starList
# 0  An eight-year-old troublemaker, mistakenly lef...             []
# 1  In November 1984, the Soviet Union's best subm...             []
# 2  Four teenage mutant ninja turtles emerge from ...             []
# 3  Stranded in 1955, Marty McFly learns about the...             []
# 4  The comic strip detective finds his life vastl...             []

# %%
#Code to check specific column based on if the column has a specific value found on https://stackoverflow.com/questions/35956712/check-if-certain-value-is-contained-in-a-dataframe-column-in-pandas
len(movie_df_dropped[movie_df_dropped['genres'].astype(str).str.contains('None')])
# Out:
# 0

# %%
len(movie_df_dropped[movie_df_dropped['genres'].astype(str).str.contains('none')])
# Out:
# 0

# %%
len(movie_df_dropped[movie_df_dropped['genres'].astype(str).str.contains('NONE')])
# Out:
# 0

# %%
len(movie_df_dropped[movie_df_dropped['genres'].astype(str).str.contains('nOne')])
# Out:
# 0

# %%
len(movie_df_dropped[movie_df_dropped['genres'].astype(str).str.contains('noNe')])
# Out:
# 0

# %%
len(movie_df_dropped[movie_df_dropped['genres'].astype(str).str.contains('nonE')])
# Out:
# 0

# %%
len(movie_df_dropped[movie_df_dropped['genres'].astype(str).str.contains('NOne')])
# Out:
# 0

# %%
len(movie_df_dropped[movie_df_dropped['genres'].astype(str).str.contains('NONe')])
# Out:
# 0

# %%
#info method on movie_df_clean to see a summary of the data
movie_df_dropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3973 entries, 0 to 3972
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             3973 non-null   int64
#  1   id                3973 non-null   object
#  2   image             3973 non-null   object
#  3   title             3973 non-null   object
#  4   description       3972 non-null   object
#  5   runtimeStr        3938 non-null   object
#  6   genres            3973 non-null   object
#  7   genreList         3973 non-null   object
#  8   contentRating     3972 non-null   object
#  9   imDbRating        3973 non-null   object
#  10  imDbRatingVotes   3973 non-null   object
#  11  metacriticRating  1470 non-null   object
#  12  plot              3973 non-null   object
#  13  stars             3973 non-null   object
#  14  starList          3973 non-null   object
# dtypes: int64(1), object(14)
# memory usage: 465.7+ KB

# %%
#Replacing all values with NaN as 'None' for ease of filtering. Code to replace values found on https://stackoverflow.com/questions/66760733/change-nan-to-none-in-pandas-dataframe
movie_df = movie_df_dropped.replace({np.nan:'None'})
movie_df[movie_df['genres'] == 'None']
# Out:
# Empty DataFrame
# Columns: [index, id, image, title, description, runtimeStr, genres, genreList, contentRating, imDbRating, imDbRatingVotes, metacriticRating, plot, stars, starList]
# Index: []

# %% [markdown]
# Looking at the above results for a few combinations of identifying null values in the genre column, it seems all data for genre seems present. However, this will be kept in mind and checked again in future steps for implementing deep learning neural network model.

# %%
#Filtering out movies with 'None' values for their genre
movie_df = movie_df[movie_df['genres'] != 'None']
movie_df
# Out:
#       level_0  index          id  \
# 0           0      0   tt0099785
# 1           1      1   tt0099810
# 2           2      2   tt0100758
# 3           3      3   tt0099088
# 4           4      4   tt0099422
# ...       ...    ...         ...
# 3968     3968   4051  tt11650502
# 3969     3969   4052  tt21862696
# 3970     3970   4053   tt0122511
# 3971     3971   4054  tt15426874
# 3972     3972   4056  tt27838714
#
#                                                   image  \
# 0     https://m.media-amazon.com/images/M/MV5BMzFkM2...
# 1     https://m.media-amazon.com/images/M/MV5BZDdkOD...
# 2     https://m.media-amazon.com/images/M/MV5BNzg3NT...
# 3     https://m.media-amazon.com/images/M/MV5BYjhlMG...
# 4     https://m.media-amazon.com/images/M/MV5BMzA5MD...
# ...                                                 ...
# 3968  https://m.media-amazon.com/images/M/MV5BODZlNG...
# 3969  https://m.media-amazon.com/images/M/MV5BYjZmND...
# 3970  https://m.media-amazon.com/images/M/MV5BMTQwMW...
# 3971  https://m.media-amazon.com/images/M/MV5BNmIwZj...
# 3972  https://m.media-amazon.com/images/M/MV5BYjkxNz...
#
#                                           title description runtimeStr  \
# 0                                    Home Alone        1990   103 mins
# 1                      The Hunt for Red October        1990   135 mins
# 2                  Teenage Mutant Ninja Turtles        1990    93 mins
# 3                   Back to the Future Part III        1990   118 mins
# 4                                    Dick Tracy        1990   105 mins
# ...                                         ...         ...        ...
# 3968                            Touch the Water        2023    94 mins
# 3969           Snow White's Christmas Adventure        2023       None
# 3970                 The Gnomes Great Adventure        2023    74 mins
# 3971  Seaper Powers: Mystery of the Blue Pearls        2023    66 mins
# 3972                                        M&A        2023    84 mins
#
#                             genres  \
# 0                   Comedy, Family
# 1      Action, Adventure, Thriller
# 2        Action, Adventure, Comedy
# 3        Adventure, Comedy, Sci-Fi
# 4            Action, Comedy, Crime
# ...                            ...
# 3968                         Drama
# 3969                        Family
# 3970  Animation, Adventure, Comedy
# 3971                     Animation
# 3972                   Documentary
#
#                                               genreList contentRating  \
# 0     [{'key': 'Comedy', 'value': 'Comedy'}, {'key':...            PG
# 1     [{'key': 'Action', 'value': 'Action'}, {'key':...            PG
# 2     [{'key': 'Action', 'value': 'Action'}, {'key':...            PG
# 3     [{'key': 'Adventure', 'value': 'Adventure'}, {...            PG
# 4     [{'key': 'Action', 'value': 'Action'}, {'key':...            PG
# ...                                                 ...           ...
# 3968               [{'key': 'Drama', 'value': 'Drama'}]            PG
# 3969             [{'key': 'Family', 'value': 'Family'}]             G
# 3970  [{'key': 'Animation', 'value': 'Animation'}, {...             G
# 3971       [{'key': 'Animation', 'value': 'Animation'}]            PG
# 3972   [{'key': 'Documentary', 'value': 'Documentary'}]            PG
#
#      imDbRating imDbRatingVotes metacriticRating  \
# 0           7.7          645257               63
# 1           7.5          212075               58
# 2           6.8          103577               51
# 3           7.4          475051               55
# 4           6.2           65117               68
# ...         ...             ...              ...
# 3968        8.4              14             None
# 3969          0               0             None
# 3970        6.1              63             None
# 3971          0               0             None
# 3972          0               0             None
#
#                                                    plot stars starList
# 0     An eight-year-old troublemaker, mistakenly lef...             []
# 1     In November 1984, the Soviet Union's best subm...             []
# 2     Four teenage mutant ninja turtles emerge from ...             []
# 3     Stranded in 1955, Marty McFly learns about the...             []
# 4     The comic strip detective finds his life vastl...             []
# ...                                                 ...   ...      ...
# 3968  When an intern at a Senior Center challenges a...             []
# 3969                                                                []
# 3970  When a bunch of dim-witted trolls steal the Ki...             []
# 3971  Emma works for NOAA as a diver and researcher....             []
# 3972  Baby Boomers own 83% of businesses. It is $10 ...             []
#
# [3973 rows x 16 columns]

# %% [markdown]
# After creating a "cleaned" dataset for no null image values, the images are then saved into the corresponding file folder for future image classification.

# %%
#For loop to save the image naming it with the movie id from the url. Images are then moved into an the approrpaite file folder 
#Actual code block not able to be retrieved for addressing errors in requests but it diagnosed error cause to not having an appropriate headers to accept application/json
#Similar explanation for headers seen on ChatGPT search https://chat.openai.com/c/85f15339-0e94-4816-a444-bf82bc5fad63 with start phrase: Python, remote forcibly closed connection, how to fix get request
#Code for handling timeouts in get requests found on https://stackoverflow.com/questions/21965484/timeout-for-python-requests-get-entire-response
for i in range(len(movie_df)-1):
    url = movie_df['image'][i]
    headers = {'accept':'application/json',}
    data = requests.get(url, headers=headers, timeout=60).content
    f = open(f"{movie_df['id'][i]}.jpg",'wb')
    f.write(data)
    f.close()

# %% [markdown]
# ## 2.5 Target Feature (Movie Genres)

# %% [markdown]
# After retreiving the movie dataset, the target feature for genres needs to be created for the output layer for the future deep learning model.

# %%
#Split genres column based on ',' in order to retrieve unique genre values for movies
#Code to split dataframe columns based on ',' found on https://stackoverflow.com/questions/14745022/how-to-split-a-dataframe-string-column-into-two-columns
movie_df[['Genre_1', 'Genre_2']] = movie_df['genres'].str.split(',', n=1, expand=True)
movie_df[['Genre_2', 'Genre_3']] = movie_df['Genre_2'].str.split(',', n=1, expand=True)
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3973 entries, 0 to 3972
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   level_0           3973 non-null   int64
#  1   index             3973 non-null   int64
#  2   id                3973 non-null   object
#  3   image             3973 non-null   object
#  4   title             3973 non-null   object
#  5   description       3973 non-null   object
#  6   runtimeStr        3973 non-null   object
#  7   genres            3973 non-null   object
#  8   genreList         3973 non-null   object
#  9   contentRating     3973 non-null   object
#  10  imDbRating        3973 non-null   object
#  11  imDbRatingVotes   3973 non-null   object
#  12  metacriticRating  3973 non-null   object
#  13  plot              3973 non-null   object
#  14  stars             3973 non-null   object
#  15  starList          3973 non-null   object
#  16  Genre_1           3973 non-null   object
#  17  Genre_2           2920 non-null   object
#  18  Genre_3           1991 non-null   object
# dtypes: int64(2), object(17)
# memory usage: 749.8+ KB

# %%
movie_df_filter = movie_df.replace({np.nan:'None'})
movie_df_filter[movie_df_filter['genres'] != 'None']
# Out:
#       level_0  index          id  \
# 0           0      0   tt0099785
# 1           1      1   tt0099810
# 2           2      2   tt0100758
# 3           3      3   tt0099088
# 4           4      4   tt0099422
# ...       ...    ...         ...
# 3968     3968   4051  tt11650502
# 3969     3969   4052  tt21862696
# 3970     3970   4053   tt0122511
# 3971     3971   4054  tt15426874
# 3972     3972   4056  tt27838714
#
#                                                   image  \
# 0     https://m.media-amazon.com/images/M/MV5BMzFkM2...
# 1     https://m.media-amazon.com/images/M/MV5BZDdkOD...
# 2     https://m.media-amazon.com/images/M/MV5BNzg3NT...
# 3     https://m.media-amazon.com/images/M/MV5BYjhlMG...
# 4     https://m.media-amazon.com/images/M/MV5BMzA5MD...
# ...                                                 ...
# 3968  https://m.media-amazon.com/images/M/MV5BODZlNG...
# 3969  https://m.media-amazon.com/images/M/MV5BYjZmND...
# 3970  https://m.media-amazon.com/images/M/MV5BMTQwMW...
# 3971  https://m.media-amazon.com/images/M/MV5BNmIwZj...
# 3972  https://m.media-amazon.com/images/M/MV5BYjkxNz...
#
#                                           title description runtimeStr  \
# 0                                    Home Alone        1990   103 mins
# 1                      The Hunt for Red October        1990   135 mins
# 2                  Teenage Mutant Ninja Turtles        1990    93 mins
# 3                   Back to the Future Part III        1990   118 mins
# 4                                    Dick Tracy        1990   105 mins
# ...                                         ...         ...        ...
# 3968                            Touch the Water        2023    94 mins
# 3969           Snow White's Christmas Adventure        2023       None
# 3970                 The Gnomes Great Adventure        2023    74 mins
# 3971  Seaper Powers: Mystery of the Blue Pearls        2023    66 mins
# 3972                                        M&A        2023    84 mins
#
#                             genres  \
# 0                   Comedy, Family
# 1      Action, Adventure, Thriller
# 2        Action, Adventure, Comedy
# 3        Adventure, Comedy, Sci-Fi
# 4            Action, Comedy, Crime
# ...                            ...
# 3968                         Drama
# 3969                        Family
# 3970  Animation, Adventure, Comedy
# 3971                     Animation
# 3972                   Documentary
#
#                                               genreList contentRating  \
# 0     [{'key': 'Comedy', 'value': 'Comedy'}, {'key':...            PG
# 1     [{'key': 'Action', 'value': 'Action'}, {'key':...            PG
# 2     [{'key': 'Action', 'value': 'Action'}, {'key':...            PG
# 3     [{'key': 'Adventure', 'value': 'Adventure'}, {...            PG
# 4     [{'key': 'Action', 'value': 'Action'}, {'key':...            PG
# ...                                                 ...           ...
# 3968               [{'key': 'Drama', 'value': 'Drama'}]            PG
# 3969             [{'key': 'Family', 'value': 'Family'}]             G
# 3970  [{'key': 'Animation', 'value': 'Animation'}, {...             G
# 3971       [{'key': 'Animation', 'value': 'Animation'}]            PG
# 3972   [{'key': 'Documentary', 'value': 'Documentary'}]            PG
#
#      imDbRating imDbRatingVotes metacriticRating  \
# 0           7.7          645257               63
# 1           7.5          212075               58
# 2           6.8          103577               51
# 3           7.4          475051               55
# 4           6.2           65117               68
# ...         ...             ...              ...
# 3968        8.4              14             None
# 3969          0               0             None
# 3970        6.1              63             None
# 3971          0               0             None
# 3972          0               0             None
#
#                                                    plot stars starList  \
# 0     An eight-year-old troublemaker, mistakenly lef...             []
# 1     In November 1984, the Soviet Union's best subm...             []
# 2     Four teenage mutant ninja turtles emerge from ...             []
# 3     Stranded in 1955, Marty McFly learns about the...             []
# 4     The comic strip detective finds his life vastl...             []
# ...                                                 ...   ...      ...
# 3968  When an intern at a Senior Center challenges a...             []
# 3969                                                                []
# 3970  When a bunch of dim-witted trolls steal the Ki...             []
# 3971  Emma works for NOAA as a diver and researcher....             []
# 3972  Baby Boomers own 83% of businesses. It is $10 ...             []
#
#           Genre_1     Genre_2    Genre_3
# 0          Comedy      Family       None
# 1          Action   Adventure   Thriller
# 2          Action   Adventure     Comedy
# 3       Adventure      Comedy     Sci-Fi
# 4          Action      Comedy      Crime
# ...           ...         ...        ...
# 3968        Drama        None       None
# 3969       Family        None       None
# 3970    Animation   Adventure     Comedy
# 3971    Animation        None       None
# 3972  Documentary        None       None
#
# [3973 rows x 19 columns]

# %%
#Stack the genre columns into one genre list, strip whitespaes, and remove duplicates and null values to retrieve target genres
#Code for stacking dataframes vertically found on https://www.geeksforgeeks.org/stack-two-pandas-series-vertically-and-horizontally/
#Code for removing whitespace found on https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.strip.html
genre_list = pd.concat([movie_df['Genre_1'], movie_df['Genre_2'], movie_df['Genre_3']], axis=0, ignore_index = True)
genres = genre_list.str.strip()
dropped = genres.drop_duplicates()
dropped.replace('',np.nan, inplace=True)
target_genres = dropped.dropna()
target_genres
# Out:
# 0            Comedy
# 1            Action
# 3         Adventure
# 7         Animation
# 11            Drama
# 52      Documentary
# 65            Crime
# 67        Biography
# 114          Family
# 130         Fantasy
# 379         Romance
# 455         Western
# 539          Horror
# 541          Sci-Fi
# 867         Musical
# 1069        History
# 1152        Mystery
# 1547       Thriller
# 2268          Music
# 2270           News
# 2780          Sport
# 4100            War
# dtype: object

# %% [markdown]
# ## 2.6 Save data

# %%
movie_df.shape
# Out:
# (3973, 19)

# %%
target_genres.shape
# Out:
# (22,)

# %%
# save the data to a new csv file
datapath = 'C:/Users/tpooz/OneDrive/Desktop/Data_Science_BootCamp_2023/SpringBoard_Github/IMDB_Classification/0_Datasets'
movie_df_filter.to_csv('C:/Users/tpooz/OneDrive/Desktop/Data_Science_BootCamp_2023/SpringBoard_Github/IMDB_Classification/0_Datasets/movie_df_clean.csv') 
target_genres.to_csv('C:/Users/tpooz/OneDrive/Desktop/Data_Science_BootCamp_2023/SpringBoard_Github/IMDB_Classification/0_Datasets/target_genres.csv')

# %% [markdown]
# ## 2.7 Summary

# %% [markdown]
# After retrieving json and "cleaning of the IMDB movie data, rows within the "image" column with the value of 'None'  were replaced with np.nan and then dropped as these specific movies without image data will not be useful for the image data classifier model. The genres were then retrieved from the "genre" column and split and duplicates were dropped in order to get an output target column for categories for movies for the future classifier model output layer. Final shape of the dataset is (3972, 18) from a (4058, 13) intial dataset. Further EDA will be conducted in order to assess genre balance within the movie_df_cleaned dataset.
